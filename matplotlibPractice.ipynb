# %% [markdown]
# ## matplotlib practice from doc

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
plt.style.use('ggplot')
mpl.rc('lines', color='b')

# %%
fig = plt.figure()
fig.suptitle('no axes')
fig, ax_lst = plt.subplots(2,2)

# %%
x = np.linspace(0,2,100)
x
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
#        1.41414141, 1.43434343, 1.45454545, 1.47474747, 1.49494949,
#        1.51515152, 1.53535354, 1.55555556, 1.57575758, 1.5959596 ,
#        1.61616162, 1.63636364, 1.65656566, 1.67676768, 1.6969697 ,
#        1.71717172, 1.73737374, 1.75757576, 1.77777778, 1.7979798 ,
#        1.81818182, 1.83838384, 1.85858586, 1.87878788, 1.8989899 ,
#        1.91919192, 1.93939394, 1.95959596, 1.97979798, 2.        ])

# %%
plt.plot(x, x, label = 'linear')
plt.plot(x, x**2, label = 'quad')
plt.plot(x, x**3, label = 'cubic')

plt.xlabel('x')
plt.ylabel('y')

plt.title("sample")

plt.legend()

# %%
x = np.arange(0, 10, 0.2)
y = np.sin(x)
fig, ax = plt.subplots()
ax.set_title('Simple plot')
ax.plot(x, y)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# %%
plt.plot([1,2,3])

# %%
plt.subplot(211)

# %%
plt.subplot(221)

# %%
# equivalent but more general
ax1=plt.subplot(2, 2, 1)

# add a subplot with no frame
ax2=plt.subplot(222, frameon=False)

# add a polar subplot
plt.subplot(223, projection='polar')

# add a red subplot that shares the x-axis with ax1
plt.subplot(224, sharex=ax1, facecolor='blue')

#delete ax2 from the figure
plt.delaxes(ax2)

#add ax2 to the figure again
plt.subplot(ax2)

# plt.clf()

plt.figure(2)                # a second figure
plt.plot([4, 5, 6])

# plt.clf()

# %%
print(plt.style.available)
# Out:
# ['seaborn-pastel', 'seaborn-paper', 'tableau-colorblind10', 'seaborn', 'seaborn-deep', 'seaborn-dark-palette', 'seaborn-notebook', 'bmh', '_classic_test', 'seaborn-bright', 'seaborn-poster', 'seaborn-ticks', 'seaborn-whitegrid', 'Solarize_Light2', 'classic', 'seaborn-darkgrid', 'seaborn-white', 'seaborn-talk', 'dark_background', 'grayscale', 'fivethirtyeight', 'ggplot', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-muted', 'fast']
